# %% [markdown]
# importing pandas library

# %%
import pandas as pd

# %% [markdown]
# reading the Churn.csv file

# %%
df=pd.read_csv('Churn.csv')

# %% [markdown]
# 5 samples of the file

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6509  0616-ATFGB    Male              1     Yes         No       1
# 3081  6376-GAHQE    Male              0      No         No       4
# 6621  6762-NSODU  Female              0     Yes        Yes      46
# 5354  4273-MBHYA  Female              0      No        Yes       1
# 2677  2608-BHKFN  Female              0      No         No       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 6509           No  No phone service             DSL                   No  ...
# 3081          Yes                No     Fiber optic                   No  ...
# 6621          Yes                No              No  No internet service  ...
# 5354          Yes                No     Fiber optic                   No  ...
# 2677          Yes                No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %% [markdown]
# geting shape values like rows and columns

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# deleting column 'customerID'

# %%
df.drop('customerID',axis='columns',inplace=True)

# %% [markdown]
# after deleting column 'customerID' , 5 samples

# %%
df.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1973    Male              0     Yes        Yes      72          Yes
# 4721    Male              0      No         No       1          Yes
# 4307  Female              1      No         No      37          Yes
# 3786    Male              0     Yes        Yes      27          Yes
# 341   Female              0     Yes         No      71          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 1973            No             DSL                  Yes                   No
# 4721            No              No  No internet service  No internet service
# 4307           Yes     Fiber optic                   No                   No
# 3786           Yes     Fiber optic                   No                   No
# 341            Yes             DSL                  Yes                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...
